# %%
import os
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

# Research paper styling
plt.style.use('default')
sns.set_palette("Set2")  # Professional color palette
plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
plt.rcParams['font.family'] = 'serif'  # Better for publications
plt.rcParams['axes.linewidth'] = 0.8
plt.rcParams['grid.alpha'] = 0.3

print("Research analysis environment ready.")
# Out:
# Research analysis environment ready.

# %%
import pandas as pd
import json

# Load the combined retrieval results
result_file = "/Users/davidsamuel/Documents/Unimelb Masters/Thesis/bible-nmt/results/gemini-2.5-flash-webp-dhao/glossary_full+parallel_full+nt_n10/gemini-2.5-flash_aligned-eng-engwebp-ot_eng_nfa-filtered_metrics.json"
with open(result_file, 'r') as f:
    data = json.load(f)

# Extract the metrics
original_metrics = data['original_mt_metrics']
post_edited_metrics = data['post_edited_metrics']
improvements = data['improvements']

# Create a clean 5-column dataframe
df_display = pd.DataFrame({
    'method': [
        'Fine-tuned NLLB',
        'Post-Editing'
    ],
    'parallel_sentence': [
        'N/A',
        'Fuzzy Word Matching_10-SHOT'
    ],
    'lexicon': [
        'N/A',
        'Full'
    ],
    'spBLEU': [
        f"{original_metrics['spbleu']:.2f}",
        f"{post_edited_metrics['spbleu']:.2f} (+{improvements['spbleu']:.2f})"
    ],
    'chrF++': [
        f"{original_metrics['chrf++']:.2f}",
        f"{post_edited_metrics['chrf++']:.2f} (+{improvements['chrf++']:.2f})"
    ]
})

print("Combined Retrieval Results")
print("=" * 80)
df_display
# Out:
# Combined Retrieval Results
# ...
#             method            parallel_sentence lexicon          spBLEU  \
# 0  Fine-tuned NLLB                          N/A     N/A            7.66
# 1     Post-Editing  Fuzzy Word Matching_10-SHOT    Full  19.88 (+12.22)
#
#           chrF++
# 0          27.11
# 1  35.21 (+8.10)
